# %%
from SNN import*

# %%
import SNN

# %%
snn = SCNN_single_conv(12,12)

# %%
fake_input = torch.zeros([4,15,12,260,346])

# %%
out_conv1 = snn.conv1(fake_input)
# out_conv2 = snn.conv2(out_conv1)

# %%
# out_conv2.shape

# %%
snn(fake_input)
# Out:
# c1_mem torch.Size([4, 15, 12, 260, 346])
# ops(x) torch.Size([4, 12, 260, 346])
# mem torch.Size([4, 12, 260, 346])
# c1_mem[:,step] torch.Size([4, 12, 260, 346])
# ops(x) torch.Size([4, 12, 260, 346])
# mem torch.Size([4, 12, 260, 346])
# c1_mem[:,step] torch.Size([4, 12, 260, 346])
# ops(x) torch.Size([4, 12, 260, 346])
# mem torch.Size([4, 12, 260, 346])
# c1_mem[:,step] torch.Size([4, 12, 260, 346])
# ops(x) torch.Size([4, 12, 260, 346])
# mem torch.Size([4, 12, 260, 346])
# c1_mem[:,step] torch.Size([4, 12, 260, 346])
# ops(x) torch.Size([4, 12, 260, 346])
# mem torch.Size([4, 12, 260, 346])
# c1_mem[:,step] torch.Size([4, 12, 260, 346])
# ops(x) torch.Size([4, 12, 260, 346])
# mem torch.Size([4, 12, 260, 346])
# c1_mem[:,step] torch.Size([4, 12, 260, 346])
# ops(x) torch.Size([4, 12, 260, 346])
# mem torch.Size([4, 12, 260, 346])
# c1_mem[:,step] torch.Size([4, 12, 260, 346])
# ops(x) torch.Size([4, 12, 260, 346])
# mem torch.Size([4, 12, 260, 346])
# ...
